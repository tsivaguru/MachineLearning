# %%
import pandas as pd

# %%
titatic_data = pd.read_csv('titanic-train.csv',index_col='PassengerId')

# %%
titatic_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 891 entries, 1 to 891
# Data columns (total 11 columns):
# Survived    891 non-null int64
# Pclass      891 non-null int64
# Name        891 non-null object
# Sex         891 non-null object
# Age         714 non-null float64
# SibSp       891 non-null int64
# Parch       891 non-null int64
# Ticket      891 non-null object
# Fare        891 non-null float64
# Cabin       204 non-null object
# Embarked    889 non-null object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 83.5+ KB

# %%
titatic_data.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# ...

# %%
#Dropping the collumn with very less useful information
titatic_data.drop('Cabin',axis=1, inplace=True)

# %%
#Finding the richest passengers
titatic_data[titatic_data.Fare == titatic_data.Fare.max()]
# Out:
#              Survived  Pclass                                Name     Sex  \
# PassengerId
# 259                 1       1                    Ward, Miss. Anna  female
# 680                 1       1  Cardeza, Mr. Thomas Drake Martinez    male
# 738                 1       1              Lesurer, Mr. Gustave J    male
#
#               Age  SibSp  Parch    Ticket      Fare Embarked
# PassengerId
# 259          35.0      0      0  PC 17755  512.3292        C
# 680          36.0      0      1  PC 17755  512.3292        C
# 738          35.0      0      0  PC 17755  512.3292        C

# %%
#Find number of male or females
titatic_data.groupby('Sex').size()
# Out:
# Sex
# female    314
# male      577
# dtype: int64

# %%
def f(age):
    if age < 18:
        return "kid"
    elif age >= 18:
        return "adult"
    else:
        return "not known"

#Adda new col which tell if the person is kid or adult or not known
titatic_data['Category'] = titatic_data.Age.map(f)

# %%
titatic_data
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# 6                   0       3
# 7                   0       1
# 8                   0       3
# 9                   1       3
# 10                  1       2
# 11                  1       3
# 12                  1       1
# 13                  0       3
# 14                  0       3
# 15                  0       3
# 16                  1       2
# 17                  0       3
# 18                  1       2
# 19                  0       3
# 20                  1       3
# 21                  0       2
# 22                  1       2
# 23                  1       3
# 24                  1       1
# 25                  0       3
# 26                  1       3
# 27                  0       3
# 28                  0       1
# 29                  1       3
# ...

# %%
#Find the person with longest name
titatic_data['NameLength'] = titatic_data.Name.str.len()
titatic_data['NameLength']
# Out:
# PassengerId
# 1      23
# 2      51
# 3      22
# 4      44
# 5      24
# 6      16
# 7      23
# 8      30
# 9      49
# 10     35
# 11     31
# 12     24
# 13     30
# 14     27
# 15     36
# 16     32
# 17     20
# 18     28
# 19     55
# 20     23
# 21     20
# 22     21
# 23     27
# 24     28
# 25     29
# 26     57
# 27     23
# 28     30
# 29     29
# 30     19
#        ..
# 862    27
# 863    51
# 864    33
# 865    22
# 866    24
# 867    28
# 868    36
# 869    27
# 870    31
# 871    17
# 872    48
# 873    24
# 874    27
# 875    37
# 876    32
# 877    29
# 878    20
# 879    18
# 880    45
# 881    44
# 882    18
# 883    28
# 884    29
# 885    22
# 886    36
# 887    21
# 888    28
# 889    40
# 890    21
# 891    19
# Name: NameLength, Length: 891, dtype: int64

# %%
titatic_data.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Embarked Category  \
# PassengerId
# 1                1      0         A/5 21171   7.2500        S    adult
# 2                1      0          PC 17599  71.2833        C    adult
# ...

# %%
#Get the row which have the person with longest name
titatic_data[titatic_data.NameLength ==  max(titatic_data.NameLength)]
# Out:
#              Survived  Pclass  \
# PassengerId
# 308                 1       1
#
#                                                           Name     Sex   Age  \
# PassengerId
# 308          Penasco y Castellana, Mrs. Victor de Satode (M...  female  17.0
#
#              SibSp  Parch    Ticket   Fare Embarked Category  NameLength
# PassengerId
# 308              1      0  PC 17758  108.9        C      kid          82

# %%
#Find rows where age is missing
titatic_data[pd.isnull(titatic_data.Age)]
# Out:
#              Survived  Pclass                                            Name  \
# PassengerId
# 6                   0       3                                Moran, Mr. James
# 18                  1       2                    Williams, Mr. Charles Eugene
# 20                  1       3                         Masselmani, Mrs. Fatima
# 27                  0       3                         Emir, Mr. Farred Chehab
# 29                  1       3                   O'Dwyer, Miss. Ellen "Nellie"
# 30                  0       3                             Todoroff, Mr. Lalio
# 32                  1       1  Spencer, Mrs. William Augustus (Marie Eugenie)
# 33                  1       3                        Glynn, Miss. Mary Agatha
# 37                  1       3                                Mamee, Mr. Hanna
# 43                  0       3                             Kraeff, Mr. Theodor
# 46                  0       3                        Rogers, Mr. William John
# ...

# %%
#Find rows where age is present
age_data = titatic_data[pd.notnull(titatic_data.Age)]
age_data
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# 7                   0       1
# 8                   0       3
# 9                   1       3
# 10                  1       2
# 11                  1       3
# 12                  1       1
# 13                  0       3
# 14                  0       3
# 15                  0       3
# 16                  1       2
# 17                  0       3
# 19                  0       3
# 21                  0       2
# 22                  1       2
# 23                  1       3
# 24                  1       1
# 25                  0       3
# 26                  1       3
# 28                  0       1
# 31                  0       1
# 34                  0       2
# 35                  0       1
# 36                  0       1
# 38                  0       3
# ...

# %%
age_data[age_data.Age == 0.42]
# Out:
#              Survived  Pclass                             Name   Sex   Age  \
# PassengerId
# 804                 1       3  Thomas, Master. Assad Alexander  male  0.42
#
#              SibSp  Parch Ticket    Fare Embarked Category  NameLength
# PassengerId
# 804              0      1   2625  8.5167        C      kid          31

# %%
#Group people based on age bracket
age_data.set_index('Age',inplace=True)

# %%
age_data.head()
# Out:
#       Survived  Pclass                                               Name  \
# Age
# 22.0         0       3                            Braund, Mr. Owen Harris
# 38.0         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 26.0         1       3                             Heikkinen, Miss. Laina
# 35.0         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 35.0         0       3                           Allen, Mr. William Henry
#
#          Sex  SibSp  Parch            Ticket     Fare Embarked Category  \
# Age
# 22.0    male      1      0         A/5 21171   7.2500        S    adult
# 38.0  female      1      0          PC 17599  71.2833        C    adult
# 26.0  female      0      0  STON/O2. 3101282   7.9250        S    adult
# 35.0  female      1      0            113803  53.1000        S    adult
# 35.0    male      0      0            373450   8.0500        S    adult
#
#       NameLength
# Age
# 22.0          23
# 38.0          51
# ...

# %%
age_data.groupby(lambda b: int(b/10)).size()

# %%
###Introducing lambda
# One liner function
# lambda a: int(a/10) - function taking one argument & returniing num/10

f = lambda a: a*2

# %%
f(10)

# %%
def f(a):
    return 2*x

# %%
#Finding mean of people between age group 10-39

#reset index because filtering is not possible on index col

age_data.reset_index(inplace=True)

age_df = age_data[(age_data.Age > 10) & (age_data.Age < 39)]

age_df
# Out:
#       Age  Survived  Pclass  \
# 0    22.0         0       3
# 1    38.0         1       1
# 2    26.0         1       3
# 3    35.0         1       1
# 4    35.0         0       3
# 7    27.0         1       3
# 8    14.0         1       2
# 11   20.0         0       3
# 13   14.0         0       3
# 16   31.0         0       3
# 17   35.0         0       2
# 18   34.0         1       2
# 19   15.0         1       3
# 20   28.0         1       1
# 22   38.0         1       3
# 23   19.0         0       1
# 26   28.0         0       1
# 28   21.0         0       3
# 29   18.0         0       3
# 30   14.0         1       3
# 32   27.0         0       2
# 34   19.0         1       3
# 35   18.0         0       3
# 37   21.0         0       3
# 39   29.0         1       2
# 41   21.0         1       2
# 42   28.5         0       3
# 44   11.0         0       3
# 45   22.0         0       3
# 46   38.0         1       1
# ..    ...       ...     ...
# 669  32.0         1       3
# ...

# %%
age_df.Age.mean()
# Out:
# 25.80549682875264

# %%
titatic_data['Age'] = titatic_data.Age.fillna(25.8)

# %%
titatic_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 891 entries, 1 to 891
# Data columns (total 12 columns):
# Survived      891 non-null int64
# Pclass        891 non-null int64
# Name          891 non-null object
# Sex           891 non-null object
# Age           891 non-null float64
# SibSp         891 non-null int64
# Parch         891 non-null int64
# Ticket        891 non-null object
# Fare          891 non-null float64
# Embarked      889 non-null object
# Category      891 non-null object
# NameLength    891 non-null int64
# dtypes: float64(2), int64(5), object(5)
# memory usage: 90.5+ KB

# %%
##Survival games
titatic_data.groupby('Survived').count()
# Out:
#           Pclass  Name  Sex  Age  SibSp  Parch  Ticket  Fare  Embarked  \
# Survived
# 0            549   549  549  549    549    549     549   549       549
# 1            342   342  342  342    342    342     342   342       340
#
#           Category  NameLength
# Survived
# 0              549         549
# 1              342         342

# %%
survivedgb = titatic_data.groupby('Survived')

# %%
#0 - Indexes of all the people who didnt survive
survivedgb.groups
# Out:
# {0: Int64Index([  1,   5,   6,   7,   8,  13,  14,  15,  17,  19,
#              ...
#              878, 879, 882, 883, 884, 885, 886, 887, 889, 891],
#             dtype='int64', name='PassengerId', length=549),
#  1: Int64Index([  2,   3,   4,   9,  10,  11,  12,  16,  18,  20,
#              ...
#              866, 867, 870, 872, 875, 876, 880, 881, 888, 890],
#             dtype='int64', name='PassengerId', length=342)}

# %%
import numpy as np
titatic_data.head()

# %%
#getting all the dead people
dead_people = titatic_data.loc[survivedgb.groups[0]]

# %%
dead_people.groupby('Pclass').size()
# Out:
# Pclass
# 1     80
# 2     97
# 3    372
# dtype: int64

# %%
dead_people.groupby('Sex').size()
# Out:
# Sex
# female     81
# male      468
# dtype: int64
